# %%
import pandas as pd

# %%
base_imdb = pd.read_csv('../data/processed/title.csv')

# %%
base_imdb
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short               Poor Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 11949941  tt9916848  tvEpisode              Episode #3.17
# 11949942  tt9916850  tvEpisode              Episode #3.19
# 11949943  tt9916852  tvEpisode              Episode #3.20
# 11949944  tt9916856      short                   The Wind
# 11949945  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita        0      1894      \N              1
# 1            Le clown et ses chiens        0      1892      \N              5
# ...

# %%
base_imdb.columns.to_list()
# Out:
# ['tconst',
#  'titleType',
#  'primaryTitle',
#  'originalTitle',
#  'isAdult',
#  'startYear',
#  'endYear',
#  'runtimeMinutes',
#  'genres']

# %%
base_imdb.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult            int64
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
base_imdb[['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'genres']] = base_imdb[['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'genres']].astype('string')

# %%
base_imdb[['titleType']] = base_imdb[['titleType']].astype('category')

# %%
base_imdb[['startYear', 'endYear', 'runtimeMinutes']] = base_imdb[['startYear', 'endYear', 'runtimeMinutes']].astype('string')

# %%
base_imdb.dtypes
# Out:
# tconst            string[python]
# titleType               category
# primaryTitle      string[python]
# originalTitle     string[python]
# isAdult                    int64
# startYear         string[python]
# endYear           string[python]
# runtimeMinutes    string[python]
# genres            string[python]
# dtype: object

# %%
base_imdb
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short               Poor Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 11949941  tt9916848  tvEpisode              Episode #3.17
# 11949942  tt9916850  tvEpisode              Episode #3.19
# 11949943  tt9916852  tvEpisode              Episode #3.20
# 11949944  tt9916856      short                   The Wind
# 11949945  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita        0      1894      \N              1
# 1            Le clown et ses chiens        0      1892      \N              5
# ...

# %%
base_imdb.isnull().sum()
# Out:
# tconst              0
# titleType           0
# primaryTitle       22
# originalTitle      22
# isAdult             0
# startYear           0
# endYear             0
# runtimeMinutes      0
# genres            610
# dtype: int64

# %%
base_imdb.isnull().sum() * 100 / len(base_imdb)
# Out:
# tconst            0.000000
# titleType         0.000000
# primaryTitle      0.000184
# originalTitle     0.000184
# isAdult           0.000000
# startYear         0.000000
# endYear           0.000000
# runtimeMinutes    0.000000
# genres            0.005105
# dtype: float64

# %%
base_imdb.isnull().mean() * 100
# Out:
# tconst            0.000000
# titleType         0.000000
# primaryTitle      0.000184
# originalTitle     0.000184
# isAdult           0.000000
# startYear         0.000000
# endYear           0.000000
# runtimeMinutes    0.000000
# genres            0.005105
# dtype: float64

# %%
base_imdb.describe()
# Out:
#             isAdult
# count  1.194995e+07
# mean   1.337025e-01
# std    1.414827e+01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    2.025000e+03

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18984\4008811067.py in ?()
# ----> 1 base_imdb = base_imdb.as_ordered()
#
# c:\Users\gusta\Desktop\ARQUIVOS PC ANTIGO\PLANOS DE AULA E LIVROS FACULDADE\CIENCIA DOS DADOS\ds_project\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'as_ordered'
