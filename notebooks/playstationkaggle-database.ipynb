# %%
#Biblioteca de visualização de dados CSV
import pandas as pd

# %%
base_playstation = pd.read_csv("../data/raw/playstation_data/game_details.csv")

# %%
base_playstation
# Out:
#                          game_name highest_price  release_date  \
# 0              Grand Theft Auto IV        €24.99  Feb 15, 2012
# 1            Red Dead Redemption 2        €59.99  Oct 26, 2018
# 2                  Red Dead Online        €69.99  Oct 29, 2018
# 3               Grand Theft Auto 3         €9.99   Oct 4, 2012
# 4               Grand Theft Auto V        €69.99  Sep 17, 2013
# ...                            ...           ...           ...
# 3521  SENRAN KAGURA Burst Re:Newal        €39.99  Jan 18, 2019
# 3522             Smash Hit Plunder        €29.99   Oct 5, 2018
# 3523                 FOX n FORESTS        €19.99  May 17, 2018
# 3524            DYNASTY WARRIORS 9        €69.99  Mar 13, 2018
# 3525                   Vostok Inc.        €14.99  Sep 22, 2017
#
#                                         genre                    publisher  \
# 0                   Action / Shooter / Racing                     Rockstar
# ...

# %%
base_playstation.describe()
# Out:
#                         release_date  metacritic_score  \
# count                           3526        879.000000
# mean   2018-10-01 03:46:39.546228224         77.470990
# min              1970-01-01 00:00:00         65.000000
# 25%              2016-04-12 00:00:00         69.000000
# 50%              2019-10-24 12:00:00         76.000000
# 75%              2022-09-22 00:00:00         85.000000
# max              2025-09-12 00:00:00         98.000000
# std                              NaN          9.003607
#
#        metacritic_rating_count  metacritic_user_score  \
# count               879.000000             880.000000
# mean                 33.407281               6.650455
# min                   4.000000               0.000000
# 25%                  10.000000               6.400000
# 50%                  24.000000               7.400000
# 75%                  50.000000               8.100000
# max                 145.000000               9.500000
# ...

# %%
#sns.countplot(x = base_playstation['game_name']);

# %%
base_playstation.columns.to_list()
# Out:
# ['game_name',
#  'highest_price',
#  'release_date',
#  'genre',
#  'publisher',
#  'platform',
#  'metacritic_score',
#  'metacritic_rating_count',
#  'metacritic_user_score',
#  'metacritic_user_rating_count',
#  'playstation_score',
#  'playstation_rating_count']

# %%
#Tipo de dados das colunas e descrições
base_playstation.info()

base_playstation.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3526 entries, 0 to 3525
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   game_name                     3526 non-null   object
#  1   highest_price                 3415 non-null   object
#  2   release_date                  3526 non-null   object
#  3   genre                         3526 non-null   object
#  4   publisher                     3471 non-null   object
#  5   platform                      3526 non-null   object
#  6   metacritic_score              879 non-null    float64
#  7   metacritic_rating_count       879 non-null    float64
#  8   metacritic_user_score         880 non-null    float64
#  9   metacritic_user_rating_count  880 non-null    float64
#  10  playstation_score             3526 non-null   object
#  11  playstation_rating_count      2557 non-null   float64
# dtypes: float64(5), object(7)
# ...

# %%
for columns in base_playstation.columns:
    print(f'Coluna: {columns} - Valores únicos: {base_playstation[columns].nunique()}')
# Out:
# Coluna: game_name - Valores únicos: 3270
# Coluna: highest_price - Valores únicos: 62
# Coluna: release_date - Valores únicos: 1731
# Coluna: genre - Valores únicos: 290
# Coluna: publisher - Valores únicos: 767
# Coluna: platform - Valores únicos: 15
# Coluna: metacritic_score - Valores únicos: 34
# Coluna: metacritic_rating_count - Valores únicos: 106
# Coluna: metacritic_user_score - Valores únicos: 65
# Coluna: metacritic_user_rating_count - Valores únicos: 420
# Coluna: playstation_score - Valores únicos: 205
# Coluna: playstation_rating_count - Valores únicos: 1541

# %%
base_playstation['game_name'].unique()
# Out:
# array(['Grand Theft Auto IV', 'Red Dead Redemption 2', 'Red Dead Online',
#        ..., 'FOX n FORESTS', 'DYNASTY WARRIORS 9', 'Vostok Inc.'],
#       shape=(3270,), dtype=object)

# %%
base_playstation[['game_name', 'genre', 'publisher', 'platform', ]] = base_playstation[['game_name', 'genre', 'publisher', 'platform']].astype('string')

# %%
base_playstation['playstation_rating_count'] = base_playstation['playstation_rating_count'].astype('object')

# %%
base_playstation.dtypes
# Out:
# game_name                       string[python]
# highest_price                           object
# release_date                            object
# genre                           string[python]
# publisher                       string[python]
# platform                        string[python]
# metacritic_score                       float64
# metacritic_rating_count                float64
# metacritic_user_score                  float64
# metacritic_user_rating_count           float64
# playstation_score                       object
# playstation_rating_count                object
# dtype: object

# %%
base_playstation['release_date'] = base_playstation['release_date'].astype('datetime64[ns]')

# %%
base_playstation
# Out:
#                          game_name highest_price release_date  \
# 0              Grand Theft Auto IV        €24.99   2012-02-15
# 1            Red Dead Redemption 2        €59.99   2018-10-26
# 2                  Red Dead Online        €69.99   2018-10-29
# 3               Grand Theft Auto 3         €9.99   2012-10-04
# 4               Grand Theft Auto V        €69.99   2013-09-17
# ...                            ...           ...          ...
# 3521  SENRAN KAGURA Burst Re:Newal        €39.99   2019-01-18
# 3522             Smash Hit Plunder        €29.99   2018-10-05
# 3523                 FOX n FORESTS        €19.99   2018-05-17
# 3524            DYNASTY WARRIORS 9        €69.99   2018-03-13
# 3525                   Vostok Inc.        €14.99   2017-09-22
#
#                                         genre                    publisher  \
# 0                   Action / Shooter / Racing                     Rockstar
# ...

# %%
base_playstation.isnull().sum()
# Out:
# game_name                          0
# highest_price                    111
# release_date                       0
# genre                              0
# publisher                         55
# platform                           0
# metacritic_score                2647
# metacritic_rating_count         2647
# metacritic_user_score           2646
# metacritic_user_rating_count    2646
# playstation_score                  0
# playstation_rating_count         969
# dtype: int64

# %%
#Porcentagem de valores nulos com 2 casas decimais
base_playstation.isnull().mean().round(4) * 100
# Out:
# game_name                        0.00
# highest_price                    3.15
# release_date                     0.00
# genre                            0.00
# publisher                        1.56
# platform                         0.00
# metacritic_score                75.07
# metacritic_rating_count         75.07
# metacritic_user_score           75.04
# metacritic_user_rating_count    75.04
# playstation_score                0.00
# playstation_rating_count        27.48
# dtype: float64

# %%
base_playstation.describe()
# Out:
#                         release_date  metacritic_score  \
# count                           3526        879.000000
# mean   2018-10-01 03:46:39.546228224         77.470990
# min              1970-01-01 00:00:00         65.000000
# 25%              2016-04-12 00:00:00         69.000000
# 50%              2019-10-24 12:00:00         76.000000
# 75%              2022-09-22 00:00:00         85.000000
# max              2025-09-12 00:00:00         98.000000
# std                              NaN          9.003607
#
#        metacritic_rating_count  metacritic_user_score  \
# count               879.000000             880.000000
# mean                 33.407281               6.650455
# min                   4.000000               0.000000
# 25%                  10.000000               6.400000
# 50%                  24.000000               7.400000
# 75%                  50.000000               8.100000
# max                 145.000000               9.500000
# ...
