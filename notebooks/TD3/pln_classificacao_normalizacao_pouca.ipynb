# %% [markdown]
# # 1 - Carregamento do dataset e tratamentos necessários

# %%
#Importação padrão do dataset e biblioteca pandas
import pandas as pd

#Carregamento do dataset de notícias
df_noticias = pd.read_csv("../../data/news/articles.csv")

#Visualização das informações do dataset
df_noticias.head()
# Out:
#                                                title  \
# 0  Lula diz que está 'lascado', mas que ainda tem...
# 1  'Decidi ser escrava das mulheres que sofrem', ...
# 2  Três reportagens da Folha ganham Prêmio Petrob...
# 3  Filme 'Star Wars: Os Últimos Jedi' ganha trail...
# 4  CBSS inicia acordos com fintechs e quer 30% do...
#
#                                                 text        date   category  \
# 0  Com a possibilidade de uma condenação impedir ...  2017-09-10      poder
# 1  Para Oumou Sangaré, cantora e ativista malines...  2017-09-10  ilustrada
# 2  Três reportagens da Folha foram vencedoras do ...  2017-09-10      poder
# 3  A Disney divulgou na noite desta segunda-feira...  2017-09-10  ilustrada
# 4  O CBSS, banco da holding Elopar dos sócios Bra...  2017-09-10    mercado
#
#   subcategory                                               link
# 0         NaN  http://www1.folha.uol.com.br/poder/2017/10/192...
# 1         NaN  http://www1.folha.uol.com.br/ilustrada/2017/10...
# 2         NaN  http://www1.folha.uol.com.br/poder/2017/10/192...
# 3         NaN  http://www1.folha.uol.com.br/ilustrada/2017/10...
# 4         NaN  http://www1.folha.uol.com.br/mercado/2017/10/1...

# %% [markdown]
# ### O Dataset tem 6 colunas, com uma delas sendo a categoria, chamada *category* e 167.053 linhas

# %%
#Resumo do dataset e contagem dos objetos não nulos
df_noticias.info()
df_noticias
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167053 entries, 0 to 167052
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   title        167053 non-null  object
#  1   text         166288 non-null  object
#  2   date         167053 non-null  object
#  3   category     167053 non-null  object
#  4   subcategory  29635 non-null   object
#  5   link         167053 non-null  object
# dtypes: object(6)
# memory usage: 7.6+ MB
#                                                     title  \
# 0       Lula diz que está 'lascado', mas que ainda tem...
# 1       'Decidi ser escrava das mulheres que sofrem', ...
# 2       Três reportagens da Folha ganham Prêmio Petrob...
# 3       Filme 'Star Wars: Os Últimos Jedi' ganha trail...
# 4       CBSS inicia acordos com fintechs e quer 30% do...
# ...                                                   ...
# 167048  Em cenário de crise, tucano Beto Richa assume ...
# 167049  Filho supera senador Renan Calheiros e assume ...
# 167050  Hoje na TV: Tottenham x Chelsea, Campeonato In...
# 167051  Kim Jong-un diz estar aberto a se reunir com p...
# 167052  Heitor Maia Neto (1928 - 2014) - Pioneiro da a...
#
#                                                      text        date  \
# 0       Com a possibilidade de uma condenação impedir ...  2017-09-10
# 1       Para Oumou Sangaré, cantora e ativista malines...  2017-09-10
# 2       Três reportagens da Folha foram vencedoras do ...  2017-09-10
# 3       A Disney divulgou na noite desta segunda-feira...  2017-09-10
# 4       O CBSS, banco da holding Elopar dos sócios Bra...  2017-09-10
# ...                                                   ...         ...
# 167048  O tucano Beto Richa tinha tudo para começar se...  2015-01-01
# 167049  O economista Renan Filho (PMDB) assume nesta q...  2015-01-01
# 167050  Destaques da programação desta quinta-feira (1...  2015-01-01
# 167051  O líder norte-coreano, Kim Jong-un, disse nest...  2015-01-01
# 167052  O projeto de que Heitor Maia Neto mais se orgu...  2015-01-01
#
#          category subcategory  \
# 0           poder         NaN
# 1       ilustrada         NaN
# 2           poder         NaN
# 3       ilustrada         NaN
# 4         mercado         NaN
# ...           ...         ...
# 167048      poder         NaN
# 167049      poder         NaN
# 167050    esporte         NaN
# 167051      mundo         NaN
# 167052  cotidiano         NaN
#
#                                                      link
# 0       http://www1.folha.uol.com.br/poder/2017/10/192...
# 1       http://www1.folha.uol.com.br/ilustrada/2017/10...
# 2       http://www1.folha.uol.com.br/poder/2017/10/192...
# 3       http://www1.folha.uol.com.br/ilustrada/2017/10...
# 4       http://www1.folha.uol.com.br/mercado/2017/10/1...
# ...                                                   ...
# 167048  http://www1.folha.uol.com.br/poder/2015/01/156...
# 167049  http://www1.folha.uol.com.br/poder/2015/01/156...
# 167050  http://www1.folha.uol.com.br/esporte/2015/01/1...
# 167051  http://www1.folha.uol.com.br/mundo/2015/01/156...
# 167052  http://www1.folha.uol.com.br/cotidiano/2015/01...
#
# [167053 rows x 6 columns]

# %% [markdown]
# ### Valores nulos existentes:
#
# - Título da notícia: 0
# - Texto da notícia: 765
# - Data da notícia: 0
# - Categoria da notícia: 0
# - Subcategoria da notícia: 137418
# - Link da notícia: 0

# %%
#Soma dos valores faltantes no dataset
df_noticias.isnull().sum()
# Out:
# title               0
# text              765
# date                0
# category            0
# subcategory    137418
# link                0
# dtype: int64

# %%
print(df_noticias.dtypes)
# Out:
# title          object
# text           object
# date           object
# category       object
# subcategory    object
# link           object
# dtype: object

# %%
#Contagem dos valores das categorias presentes no dataset
df_noticias['category'].value_counts()
# Out:
# category
# poder                           22022
# colunas                         21622
# mercado                         20970
# esporte                         19730
# mundo                           17130
# cotidiano                       16967
# ilustrada                       16345
# opiniao                          4525
# paineldoleitor                   4011
# saopaulo                         3955
# tec                              2260
# tv                               2142
# educacao                         2118
# turismo                          1903
# ilustrissima                     1411
# ciencia                          1335
# equilibrioesaude                 1312
# sobretudo                        1057
# bbc                               980
# folhinha                          876
# empreendedorsocial                841
# comida                            828
# asmais                            548
# ambiente                          491
# seminariosfolha                   379
# serafina                          334
# o-melhor-de-sao-paulo             189
# vice                              146
# guia-de-livros-discos-filmes      143
# topofmind                          86
# banco-de-dados                     64
# dw                                 48
# infograficos                       43
# cenarios-2017                      43
# especial                           43
# rfi                                29
# guia-de-livros-filmes-discos       28
# multimidia                         27
# treinamento                        21
# treinamentocienciaesaude           18
# mulher                             16
# euronews                            8
# ombudsman                           3
# contas-de-casa                      2
# musica                              1
# 2016                                1
# bichos                              1
# 2015                                1
# Name: count, dtype: int64

# %% [markdown]
# ### Nota-se um desbalanceamento após a 7° caregoria, então a análise não conterá todas as 48 categorias, apenas as 7 mais abrangentes

# %%
#Categorias com mais notícias
top_categories = [
    "poder",
    "colunas",
    "mercado",
    "esporte",
    "mundo",
    "cotidiano",
    "ilustrada"
]

# %%
#Surgimento da cópia do novo dataset, agora com as categorias filtradas
df_noticias_filtrado = df_noticias[df_noticias["category"].isin(top_categories)].copy()

df_noticias_filtrado["category"].value_counts()
# Out:
# category
# poder        22022
# colunas      21622
# mercado      20970
# esporte      19730
# mundo        17130
# cotidiano    16967
# ilustrada    16345
# Name: count, dtype: int64

# %% [markdown]
# ### Os dados foram mantidos com o tipo object, pois todos eram textuais/strings

# %%
df_noticias_filtrado.columns
# Out:
# Index(['title', 'text', 'date', 'category', 'subcategory', 'link'], dtype='object')

# %% [markdown]
# ### Antes de tudo, preencheremos com string vazia os valores em **text** que não possuem informação

# %%
df_noticias_filtrado.isnull().sum()
# Out:
# title               0
# text              731
# date                0
# category            0
# subcategory    109331
# link                0
# dtype: int64

# %%
#Preenchimento com string vazia os valores nulos, para que não haja valores faltantes
df_noticias_filtrado["text"] = df_noticias_filtrado["text"].fillna("")
df_noticias_filtrado["title"] = df_noticias_filtrado["title"].fillna("")
df_noticias_filtrado["subcategory"] = df_noticias_filtrado["subcategory"].fillna("desconhecida")

# %%
#Concatenação das colunas titulo + text, que são 2 segmentos complementares, ajudará o modelo no desempenho
df_noticias_filtrado["texto"] = df_noticias_filtrado["title"] + " " + df_noticias_filtrado["text"]

# %%
df_noticias_filtrado["texto"].isna().sum()
df_noticias_filtrado.isnull().sum()
# Out:
# title          0
# text           0
# date           0
# category       0
# subcategory    0
# link           0
# texto          0
# dtype: int64

# %% [markdown]
# ### Decidiu-se por utilizar as colunas **title** + **text**, para maior robustez, então unificou-se as colunas em uma única variável chamada **texto**

# %%
df_noticias_filtrado
# Out:
#                                                     title  \
# 0       Lula diz que está 'lascado', mas que ainda tem...
# 1       'Decidi ser escrava das mulheres que sofrem', ...
# 2       Três reportagens da Folha ganham Prêmio Petrob...
# 3       Filme 'Star Wars: Os Últimos Jedi' ganha trail...
# 4       CBSS inicia acordos com fintechs e quer 30% do...
# ...                                                   ...
# 167048  Em cenário de crise, tucano Beto Richa assume ...
# 167049  Filho supera senador Renan Calheiros e assume ...
# 167050  Hoje na TV: Tottenham x Chelsea, Campeonato In...
# 167051  Kim Jong-un diz estar aberto a se reunir com p...
# 167052  Heitor Maia Neto (1928 - 2014) - Pioneiro da a...
#
#                                                      text        date  \
# 0       Com a possibilidade de uma condenação impedir ...  2017-09-10
# 1       Para Oumou Sangaré, cantora e ativista malines...  2017-09-10
# 2       Três reportagens da Folha foram vencedoras do ...  2017-09-10
# 3       A Disney divulgou na noite desta segunda-feira...  2017-09-10
# 4       O CBSS, banco da holding Elopar dos sócios Bra...  2017-09-10
# ...                                                   ...         ...
# 167048  O tucano Beto Richa tinha tudo para começar se...  2015-01-01
# 167049  O economista Renan Filho (PMDB) assume nesta q...  2015-01-01
# 167050  Destaques da programação desta quinta-feira (1...  2015-01-01
# 167051  O líder norte-coreano, Kim Jong-un, disse nest...  2015-01-01
# 167052  O projeto de que Heitor Maia Neto mais se orgu...  2015-01-01
#
#          category   subcategory  \
# 0           poder  desconhecida
# 1       ilustrada  desconhecida
# 2           poder  desconhecida
# 3       ilustrada  desconhecida
# 4         mercado  desconhecida
# ...           ...           ...
# 167048      poder  desconhecida
# 167049      poder  desconhecida
# 167050    esporte  desconhecida
# 167051      mundo  desconhecida
# 167052  cotidiano  desconhecida
#
#                                                      link  \
# 0       http://www1.folha.uol.com.br/poder/2017/10/192...
# 1       http://www1.folha.uol.com.br/ilustrada/2017/10...
# 2       http://www1.folha.uol.com.br/poder/2017/10/192...
# 3       http://www1.folha.uol.com.br/ilustrada/2017/10...
# 4       http://www1.folha.uol.com.br/mercado/2017/10/1...
# ...                                                   ...
# 167048  http://www1.folha.uol.com.br/poder/2015/01/156...
# 167049  http://www1.folha.uol.com.br/poder/2015/01/156...
# 167050  http://www1.folha.uol.com.br/esporte/2015/01/1...
# 167051  http://www1.folha.uol.com.br/mundo/2015/01/156...
# 167052  http://www1.folha.uol.com.br/cotidiano/2015/01...
#
#                                                     texto
# 0       Lula diz que está 'lascado', mas que ainda tem...
# 1       'Decidi ser escrava das mulheres que sofrem', ...
# 2       Três reportagens da Folha ganham Prêmio Petrob...
# 3       Filme 'Star Wars: Os Últimos Jedi' ganha trail...
# 4       CBSS inicia acordos com fintechs e quer 30% do...
# ...                                                   ...
# 167048  Em cenário de crise, tucano Beto Richa assume ...
# 167049  Filho supera senador Renan Calheiros e assume ...
# 167050  Hoje na TV: Tottenham x Chelsea, Campeonato In...
# 167051  Kim Jong-un diz estar aberto a se reunir com p...
# 167052  Heitor Maia Neto (1928 - 2014) - Pioneiro da a...
#
# [134786 rows x 7 columns]

# %% [markdown]
# ### Para visualizar se essa unificação funcionou

# %%
df_noticias_filtrado[["title", "text", "texto"]].head()
# Out:
#                                                title  \
# 0  Lula diz que está 'lascado', mas que ainda tem...
# 1  'Decidi ser escrava das mulheres que sofrem', ...
# 2  Três reportagens da Folha ganham Prêmio Petrob...
# 3  Filme 'Star Wars: Os Últimos Jedi' ganha trail...
# 4  CBSS inicia acordos com fintechs e quer 30% do...
#
#                                                 text  \
# 0  Com a possibilidade de uma condenação impedir ...
# 1  Para Oumou Sangaré, cantora e ativista malines...
# 2  Três reportagens da Folha foram vencedoras do ...
# 3  A Disney divulgou na noite desta segunda-feira...
# 4  O CBSS, banco da holding Elopar dos sócios Bra...
#
#                                                texto
# 0  Lula diz que está 'lascado', mas que ainda tem...
# 1  'Decidi ser escrava das mulheres que sofrem', ...
# 2  Três reportagens da Folha ganham Prêmio Petrob...
# 3  Filme 'Star Wars: Os Últimos Jedi' ganha trail...
# 4  CBSS inicia acordos com fintechs e quer 30% do...

# %% [markdown]
# ### Agora iremos normalizar o texto, aproveitando-se da função que o Professor deixou no notebook da aula

# %%
#Normalização que foi feita nas informações, agora sem remover os números
import re
def clean_text(text: str) -> str:
    # Garantir que é string
    text = str(text)
    # Lowercase
    text = text.lower()
    # Remover URLs
    text = re.sub(r'https?://\S+|www\.\S+', ' URL ', text)
    # Agora não normalizaremos os números, assim iremos testar para ver a melhora ou piora
    #text = re.sub(r'\d+', ' NUM ', text)
    # Remover pontuação básica
    text = re.sub(r'[\.,;:!\?"\'\(\)\-_/]', ' ', text)
    # Remover múltiplos espaços
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df_noticias_filtrado["texto"] = df_noticias_filtrado["texto"].apply(clean_text)

# %%
df_noticias_filtrado["texto"]
# Out:
# 0         lula diz que está lascado mas que ainda tem fo...
# 1         decidi ser escrava das mulheres que sofrem diz...
# 2         três reportagens da folha ganham prêmio petrob...
# 3         filme star wars os últimos jedi ganha trailer ...
# 4         cbss inicia acordos com fintechs e quer 30% do...
#                                 ...
# 167048    em cenário de crise tucano beto richa assume s...
# 167049    filho supera senador renan calheiros e assume ...
# 167050    hoje na tv tottenham x chelsea campeonato ingl...
# 167051    kim jong un diz estar aberto a se reunir com p...
# 167052    heitor maia neto 1928 2014 pioneiro da arquite...
# Name: texto, Length: 134786, dtype: object

# %% [markdown]
# ### O que foi feito até agora?
#
# #### Dataset escolhido - Notícias da Folha de São Paulo - Kaggle.
# #### Textos em português.
# #### Coluna alvo para classificar - category.
# #### Colunas ['title', 'text', 'date', 'category', 'subcategory', 'link'], ignoradas colunas não utilizadas, tratados valores nulos nas relevantes.
# #### 48 categorias em **"category"**, notou-se alto desbalanceamento com categorias pouquíssimo presentes, então manteve-se as 7 mais balanceadas.
# #### Criação de uma coluna unificada de texto para aproveitar-se melhor da manchete + corpo da notícia
# #### Aplicação da função de normalização disponibilizada pelo Prof. Renan no notebook, com lowercase removendo urls, numeros, pontuação básica e normalizando espaços (acentuação mantida).

# %% [markdown]
# # 2 - Divisão em conjunto de treino e teste

# %%
#Importação da biblioteca de separação 
from sklearn.model_selection import train_test_split

X = df_noticias_filtrado["texto"] #É o que será recebido como entrada
y = df_noticias_filtrado["category"] #É o alvo que será predito

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2, #20% do conjunto para teste
    random_state=42, #Garantia da separação dos dados de maneira pseudoaleatória
    stratify=y  #Mantendo a proporção das categorias, mesmo elas tendo quantidades parecidas
)

# %% [markdown]
# ## Representação com Bag of Words

# %% [markdown]
# #### Criação de um baseline simples, qual desempenho obteríamos com unigramas, sem filtros e usando classificador simples

# %%
#Teste simples com o Bag of Words
from sklearn.feature_extraction.text import CountVectorizer

#Código que quebra o texto em palavras e conta quantas vezes ela aparece, transformando-os em representações numéricas
vectorizer_bow = CountVectorizer()
X_train_bow = vectorizer_bow.fit_transform(X_train)
X_test_bow = vectorizer_bow.transform(X_test)

# %% [markdown]
# #### Treinamento do classificador usando o Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

#Treinamento com o Naive Bayes
model_bow = MultinomialNB()
model_bow.fit(X_train_bow, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# #### Avaliação das métricas após o treinamento com esse teste simples

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred_bow = model_bow.predict(X_test_bow)

print("Accuracy (BoW):", accuracy_score(y_test, y_pred_bow))
print(classification_report(y_test, y_pred_bow))
# Out:
# Accuracy (BoW): 0.8265079011796127
#               precision    recall  f1-score   support
#
#      colunas       0.77      0.52      0.62      4325
#    cotidiano       0.82      0.86      0.84      3393
#      esporte       0.94      0.93      0.93      3946
#    ilustrada       0.82      0.92      0.86      3269
#      mercado       0.78      0.83      0.80      4194
#        mundo       0.89      0.91      0.90      3426
#        poder       0.79      0.87      0.83      4405
#
#     accuracy                           0.83     26958
#    macro avg       0.83      0.83      0.83     26958
# weighted avg       0.82      0.83      0.82     26958

# %% [markdown]
# # Representação com TF-IDF

# %% [markdown]
# #### Vetorização com TF-IDF, semelhante ao Bag of Words, mas com suas particularidades de pesar as palavras

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


vectorizer_tfidf = TfidfVectorizer()
X_train_tfidf = vectorizer_tfidf.fit_transform(X_train)
X_test_tfidf = vectorizer_tfidf.transform(X_test)

# %% [markdown]
# #### Treinamento do classificador usando o Naive Bayes

# %%
model_tfidf = MultinomialNB()
model_tfidf.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# #### Avaliação das métricas após o treinamento

# %%
y_pred_tfidf = model_tfidf.predict(X_test_tfidf)

print("Accuracy (TF-IDF):", accuracy_score(y_test, y_pred_tfidf))
print(classification_report(y_test, y_pred_tfidf))
# Out:
# Accuracy (TF-IDF): 0.8038430150604644
#               precision    recall  f1-score   support
#
#      colunas       0.60      0.62      0.61      4325
#    cotidiano       0.89      0.74      0.81      3393
#      esporte       0.94      0.92      0.93      3946
#    ilustrada       0.92      0.76      0.84      3269
#      mercado       0.76      0.84      0.80      4194
#        mundo       0.93      0.84      0.88      3426
#        poder       0.74      0.91      0.81      4405
#
#     accuracy                           0.80     26958
#    macro avg       0.82      0.80      0.81     26958
# weighted avg       0.81      0.80      0.81     26958

# %% [markdown]
# #### Até o momento, foi treinado com as duas representações pedidas, utilizando o Classificador Naive Bayes, obtivemos a criação do Bag of Words e do TF-IDF e o teste com Naive Bayes

# %% [markdown]
# #### Agora será feito treinamento com diferentes classificadores e depois a comparação dos resultados

# %%
#Todos os imports necessários para rodar o treinamento e as métricas

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#Vetorização com Bag of Words, com os hiperparâmetros da descrição do trabalho, no entanto, aqui está utilizando trigramas
bow_vectorizer = CountVectorizer(
    ngram_range=(1, 3),
    min_df=5,
    max_df=0.9
)

X_train_bow = bow_vectorizer.fit_transform(X_train)
X_test_bow = bow_vectorizer.transform(X_test)

# %% [markdown]
# #### Criação de uma função de treino e avaliação

# %%
#Função de treino e avaliação com as métricas principais selecionadas
def treinar_e_avaliar(modelo, X_train, X_test, y_train, y_test):
    modelo.fit(X_train, y_train)
    y_pred = modelo.predict(X_test)

    resultados = {
        "accuracy": accuracy_score(y_test, y_pred),
        "precision_macro": precision_score(y_test, y_pred, average='macro'),
        "recall_macro": recall_score(y_test, y_pred, average='macro'),
        "f1_macro": f1_score(y_test, y_pred, average='macro'),
        "confusion_matrix": confusion_matrix(y_test, y_pred)
    }

    return resultados

# %% [markdown]
# ### Agora é rodar os modelos com o Bag of Words e obter o desempenho de cada uma delas

# %%
# Os 5 modelos de classificação escolhidos para o trabalho
modelos = {
    "Naive Bayes": MultinomialNB(),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM Linear": LinearSVC(),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "KNN": KNeighborsClassifier(n_neighbors=5)
}

print("Resultados — Bag of Words\n")

for nome, modelo in modelos.items():
    resultados = treinar_e_avaliar(
        modelo,
        X_train_bow,
        X_test_bow,
        y_train,
        y_test
    )

    print(
        f"{nome}: "
        f"Acc={resultados['accuracy']:.4f} | "
        f"Prec={resultados['precision_macro']:.4f} | "
        f"Rec={resultados['recall_macro']:.4f} | "
        f"F1={resultados['f1_macro']:.4f}"
    )
# Out:
# Resultados — Bag of Words
#
# Naive Bayes: Acc=0.8466 | Prec=0.8465 | Rec=0.8543 | F1=0.8470
# Logistic Regression: Acc=0.9250 | Prec=0.9256 | Rec=0.9268 | F1=0.9261
# c:\Users\gusta\Desktop\ARQUIVOS PC ANTIGO\PLANOS DE AULA E LIVROS FACULDADE\CIENCIA DOS DADOS\Data-Science---Projects\venv\Lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# SVM Linear: Acc=0.9258 | Prec=0.9263 | Rec=0.9275 | F1=0.9268
# Random Forest: Acc=0.8494 | Prec=0.8523 | Rec=0.8529 | F1=0.8501
# KNN: Acc=0.3535 | Prec=0.6351 | Rec=0.3611 | F1=0.3725

# %% [markdown]
# # ETAPA COM TF-IDF

# %% [markdown]
# #### O processo é parecido, basta alterar algumas partes, treinando com hiperparâmetros, de acordo com a descrição do trabalho

# %%
#TF-IDF com os hiperparâmetros definidos na descrição do trabalho
tfidf = TfidfVectorizer(
    ngram_range=(1,2), #Utilizando bigramas
    min_df=5, #Remoção de palavras que aparecem menos de 5 vezes
    max_df=0.8, #Remoção de palavras que aparecem em mais de 80% dos documentos
    sublinear_tf=True #Aplicação da escala descrita na descrição do trabalho, que ajuda a equilibrar os pesos
)

X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %% [markdown]
# ### Agora é rodar os modelos com o TF-IDF e obter o desempenho de cada uma delas

# %%
# Os 5 Modelos utilizados, novamente os mesmos
modelos = {
    "Naive Bayes": MultinomialNB(),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM Linear": LinearSVC(),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "KNN": KNeighborsClassifier(n_neighbors=5)
}

print("Resultados — TF-IDF\n")

resultados_tfidf = {}

for nome, modelo in modelos.items():
    resultados = treinar_e_avaliar(
        modelo,
        X_train_tfidf,
        X_test_tfidf,
        y_train,
        y_test
    )

    resultados_tfidf[nome] = resultados

    print(
        f"{nome}: "
        f"Acc={resultados['accuracy']:.4f} | "
        f"Prec={resultados['precision_macro']:.4f} | "
        f"Rec={resultados['recall_macro']:.4f} | "
        f"F1={resultados['f1_macro']:.4f}"
    )
# Out:
# Resultados — TF-IDF
#
# Naive Bayes: Acc=0.8152 | Prec=0.8313 | Rec=0.8160 | F1=0.8202
# Logistic Regression: Acc=0.9151 | Prec=0.9157 | Rec=0.9177 | F1=0.9166
# SVM Linear: Acc=0.9369 | Prec=0.9371 | Rec=0.9388 | F1=0.9379
# Random Forest: Acc=0.8500 | Prec=0.8531 | Rec=0.8538 | F1=0.8508
# KNN: Acc=0.8774 | Prec=0.8790 | Rec=0.8844 | F1=0.8745

# %% [markdown]
# #### Tabela comparativa das métricas obtidas
# | Representação | Modelo              | Accuracy   | Precision  | Recall     | F1-score   |
# | ------------- | ------------------- | ---------- | ---------- | ---------- | ---------- |
# | Bag of Words  | Naive Bayes         | 0.8466     | 0.8465     | 0.8543     | 0.8470     |
# | Bag of Words  | Logistic Regression | 0.9250     | 0.9256     | 0.9268     | 0.9261     |
# | Bag of Words  | SVM Linear          | 0.9258     | 0.9263     | 0.9275     | 0.9268     |
# | Bag of Words  | Random Forest       | 0.8494     | 0.8523     | 0.8529     | 0.8501     |
# | Bag of Words  | KNN                 | 0.3535     | 0.6351     | 0.3611     | 0.3725     |
# | TF-IDF        | Naive Bayes         | 0.8152     | 0.8313     | 0.8160     | 0.8202     |
# | TF-IDF        | Logistic Regression | 0.9151     | 0.9157     | 0.9177     | 0.9166     |
# | TF-IDF        | **SVM Linear**      | **0.9369** | **0.9371** | **0.9388** | **0.9379** |
# | TF-IDF        | Random Forest       | 0.8500     | 0.8531     | 0.8538     | 0.8508     |
# | TF-IDF        | KNN                 | 0.8774     | 0.8790     | 0.8844     | 0.8745     |

# %% [markdown]
# # VISUALIZAÇÃO DOS DADOS - NUVEM DE PALAVRAS

# %% [markdown]
# #### Fornecendo uma visualização qualitativa dos termos mais recorrentes nos textos.

# %% [markdown]
# ##### Nuvem de palavras com o Bag of Words, para visualização das palavras mais comuns no dataset

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Frequências totais das palavras no BoW
freqs_bow = dict(zip(
    bow_vectorizer.get_feature_names_out(),
    X_train_bow.sum(axis=0).A1
))

wc_bow = WordCloud(
    width=1000, height=500,
    background_color="white",
    max_words=200,
    colormap="viridis"
).generate_from_frequencies(freqs_bow)

plt.figure(figsize=(12,6))
plt.imshow(wc_bow, interpolation="bilinear")
plt.axis("off")
plt.title("Nuvem de Palavras - Bag of Words", fontsize=16)
plt.show()

# %% [markdown]
# ##### Nuvem de palavras com o TF-IDF

# %%
# Frequências ponderadas pelo TF-IDF
freqs_tfidf = dict(zip(
    tfidf.get_feature_names_out(),
    X_train_tfidf.sum(axis=0).A1
))

wc_tfidf = WordCloud(
    width=1000, height=500,
    background_color="white",
    max_words=200,
    colormap="plasma"
).generate_from_frequencies(freqs_tfidf)

plt.figure(figsize=(12,6))
plt.imshow(wc_tfidf, interpolation="bilinear")
plt.axis("off")
plt.title("Nuvem de Palavras - TF-IDF", fontsize=16)
plt.show()

# %% [markdown]
# ### Matriz de confusão do melhor modelo, SVM Linear com o TF-IDF

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.svm import LinearSVC
import numpy as np

# Treinar novamente o melhor modelo, pois anteriormente foi tudo treinado de uma vez só dentro do for
svm_best = LinearSVC()
svm_best.fit(X_train_tfidf, y_train)

# Previsões
y_pred_svm_tfidf = svm_best.predict(X_test_tfidf)

# Matriz de confusão absoluta
cm = confusion_matrix(y_test, y_pred_svm_tfidf)

# Plotar matriz absoluta
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel('Rótulos verdadeiros')
plt.xlabel('Previsões do modelo')
plt.title('Matriz de Confusão - SVM Linear com TF-IDF')
plt.show()

# %% [markdown]
# # Matriz de confusão dos outros modelos de TF-IDF

# %% [markdown]
# ### Naive Bayes TF-IDF

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

nb_tfidf = MultinomialNB()
nb_tfidf.fit(X_train_tfidf, y_train)

y_pred_nb = nb_tfidf.predict(X_test_tfidf)

cm_nb = confusion_matrix(y_test, y_pred_nb)

plt.figure(figsize=(8,6))
sns.heatmap(cm_nb, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel("Rótulos verdadeiros")
plt.xlabel("Previsões do modelo")
plt.title("Matriz de Confusão — Naive Bayes com TF-IDF")
plt.show()

# %% [markdown]
# ### Logistic Regression TF-IDF

# %%
from sklearn.linear_model import LogisticRegression

lr_tfidf = LogisticRegression(max_iter=1000)
lr_tfidf.fit(X_train_tfidf, y_train)

y_pred_lr = lr_tfidf.predict(X_test_tfidf)

cm_lr = confusion_matrix(y_test, y_pred_lr)

plt.figure(figsize=(8,6))
sns.heatmap(cm_lr, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel("Rótulos verdadeiros")
plt.xlabel("Previsões do modelo")
plt.title("Matriz de Confusão — Logistic Regression com TF-IDF")
plt.show()

# %% [markdown]
# ### Random Forest - TF-IDF

# %%
from sklearn.ensemble import RandomForestClassifier

rf_tfidf = RandomForestClassifier(n_estimators=100, random_state=42)
rf_tfidf.fit(X_train_tfidf, y_train)

y_pred_rf = rf_tfidf.predict(X_test_tfidf)

cm_rf = confusion_matrix(y_test, y_pred_rf)

plt.figure(figsize=(8,6))
sns.heatmap(cm_rf, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel("Rótulos verdadeiros")
plt.xlabel("Previsões do modelo")
plt.title("Matriz de Confusão — Random Forest com TF-IDF")
plt.show()

# %% [markdown]
# ### KNN TF-IDF

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_tfidf = KNeighborsClassifier(n_neighbors=5)
knn_tfidf.fit(X_train_tfidf, y_train)

y_pred_knn = knn_tfidf.predict(X_test_tfidf)

cm_knn = confusion_matrix(y_test, y_pred_knn)

plt.figure(figsize=(8,6))
sns.heatmap(cm_knn, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel("Rótulos verdadeiros")
plt.xlabel("Previsões do modelo")
plt.title("Matriz de Confusão — KNN com TF-IDF")
plt.show()

# %% [markdown]
# # Matriz de confusão dos outros modelos usando o Bag of Words

# %% [markdown]
# ### Naive Bayes Bag of Words

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

nb_bow = MultinomialNB()
nb_bow.fit(X_train_bow, y_train)

y_pred_nb_bow = nb_bow.predict(X_test_bow)

cm_nb_bow = confusion_matrix(y_test, y_pred_nb_bow)

plt.figure(figsize=(8,6))
sns.heatmap(cm_nb_bow, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel("Rótulos verdadeiros")
plt.xlabel("Previsões do modelo")
plt.title("Matriz de Confusão — Naive Bayes com Bag of Words")
plt.show()

# %% [markdown]
# ### Logistic Regression Bag of Words

# %%
from sklearn.linear_model import LogisticRegression

lr_bow = LogisticRegression(max_iter=1000)
lr_bow.fit(X_train_bow, y_train)

y_pred_lr_bow = lr_bow.predict(X_test_bow)

cm_lr_bow = confusion_matrix(y_test, y_pred_lr_bow)

plt.figure(figsize=(8,6))
sns.heatmap(cm_lr_bow, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel("Rótulos verdadeiros")
plt.xlabel("Previsões do modelo")
plt.title("Matriz de Confusão — Logistic Regression com Bag of Words")
plt.show()

# %% [markdown]
# ### SVM Bag of Words

# %%
from sklearn.svm import LinearSVC

svm_bow = LinearSVC()
svm_bow.fit(X_train_bow, y_train)

y_pred_svm_bow = svm_bow.predict(X_test_bow)

cm_svm_bow = confusion_matrix(y_test, y_pred_svm_bow)

plt.figure(figsize=(8,6))
sns.heatmap(cm_svm_bow, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel("Rótulos verdadeiros")
plt.xlabel("Previsões do modelo")
plt.title("Matriz de Confusão — SVM Linear com Bag of Words")
plt.show()
# Out:
# c:\Users\gusta\Desktop\ARQUIVOS PC ANTIGO\PLANOS DE AULA E LIVROS FACULDADE\CIENCIA DOS DADOS\Data-Science---Projects\venv\Lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# ### Random Forest Bag of Words

# %%
from sklearn.ensemble import RandomForestClassifier

rf_bow = RandomForestClassifier(n_estimators=100, random_state=42)
rf_bow.fit(X_train_bow, y_train)

y_pred_rf_bow = rf_bow.predict(X_test_bow)

cm_rf_bow = confusion_matrix(y_test, y_pred_rf_bow)

plt.figure(figsize=(8,6))
sns.heatmap(cm_rf_bow, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel("Rótulos verdadeiros")
plt.xlabel("Previsões do modelo")
plt.title("Matriz de Confusão — Random Forest com Bag of Words")
plt.show()

# %% [markdown]
# ### KNN Bag of Words

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_bow = KNeighborsClassifier(n_neighbors=5)
knn_bow.fit(X_train_bow, y_train)

y_pred_knn_bow = knn_bow.predict(X_test_bow)

cm_knn_bow = confusion_matrix(y_test, y_pred_knn_bow)

plt.figure(figsize=(8,6))
sns.heatmap(cm_knn_bow, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test),
            yticklabels=np.unique(y_test))
plt.ylabel("Rótulos verdadeiros")
plt.xlabel("Previsões do modelo")
plt.title("Matriz de Confusão — KNN com Bag of Words")
plt.show()
